# %% [markdown]
# # Environment

# %% [markdown]
# ### GPU

# %%
# !nvidia-smi
# Out:
# Sat Nov 18 19:49:19 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    23W / 300W |      0MiB / 16384MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### Dependency

# %%
# !pip -q install langchain huggingface_hub google-search-results tiktoken wikipedia

# %%
# !pip install bpemb sentence_transformers numpy
# Out:
# Requirement already satisfied: bpemb in /usr/local/lib/python3.10/dist-packages (0.3.4)
# Requirement already satisfied: sentence_transformers in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.23.5)
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (from bpemb) (4.3.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from bpemb) (2.31.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from bpemb) (0.1.99)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from bpemb) (4.66.1)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.35.2)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (2.1.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.16.0+cu118)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.11.3)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (3.8.1)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.19.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2023.6.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (23.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2023.6.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.4.0)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim->bpemb) (6.4.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence_transformers) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence_transformers) (1.3.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->bpemb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->bpemb) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->bpemb) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->bpemb) (2023.7.22)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (3.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence_transformers) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence_transformers) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence_transformers) (1.3.0)

# %%
# !pip install pinecone-client faiss-cpu
# Out:
# Requirement already satisfied: pinecone-client in /usr/local/lib/python3.10/dist-packages (2.2.4)
# Requirement already satisfied: faiss-cpu in /usr/local/lib/python3.10/dist-packages (1.7.4)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pinecone-client) (2.31.0)
# Requirement already satisfied: pyyaml>=5.4 in /usr/local/lib/python3.10/dist-packages (from pinecone-client) (6.0.1)
# Requirement already satisfied: loguru>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from pinecone-client) (0.7.2)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.10/dist-packages (from pinecone-client) (4.5.0)
# Requirement already satisfied: dnspython>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pinecone-client) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from pinecone-client) (2.8.2)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from pinecone-client) (2.0.7)
# Requirement already satisfied: tqdm>=4.64.1 in /usr/local/lib/python3.10/dist-packages (from pinecone-client) (4.66.1)
# Requirement already satisfied: numpy>=1.22.0 in /usr/local/lib/python3.10/dist-packages (from pinecone-client) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.5.3->pinecone-client) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pinecone-client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pinecone-client) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pinecone-client) (2023.7.22)

# %%
# !pip install gitpython
# Out:
# Requirement already satisfied: gitpython in /usr/local/lib/python3.10/dist-packages (3.1.40)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython) (4.0.11)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython) (5.0.1)

# %% [markdown]
# ### Library

# %%
import langchain
import os
import git
import json

# %% [markdown]
# ### Home

# %%
class GitHome():

    def __init__(self,
                 work_dir,
                 branch_name,
                 repo_name,
                 repo_home,
                 user_name,
                 user_token):
        ### Save
        os.environ["WORK_DIR"] = work_dir
        os.environ["BRANCH_NAME"] = branch_name
        os.environ["REPO_NAME"] = repo_name
        os.environ["GIT_HOME"] = repo_home
        os.environ["USER_NAME"] = user_name
        os.environ["USER_TOKEN"] = user_token # Github Personal Access Token
        ### Compose
        os.environ["GIT_REPO"] = os.environ["GIT_HOME"] + os.environ["REPO_NAME"]
        os.environ["REPO_DIR"] = os.environ["WORK_DIR"] + "/" + os.environ["REPO_NAME"]
        os.environ["CLONE_FROM"] = "https://" + os.environ["USER_NAME"] + ":" + os.environ["USER_TOKEN"] + "@github.com/" + os.environ["USER_NAME"] + "/" + os.environ["REPO_NAME"] + ".git"

# %%
GitHome(work_dir="/content/drive/MyDrive/StanfordLLM/thought-distillation",
        repo_name="thought-distillation",
        repo_home="https://github.com/pablo-tech/",
        branch_name="main",
        user_name="pablo-tech",
        user_token="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")

# %% [markdown]
# ### Git

# %%
os.environ["WORK_DIR"]
# Out:
# '/content/drive/MyDrive/StanfordLLM/thought-distillation'

# %%
try:
  os.chdir(os.environ["WORK_DIR"])
except:
  pass

# !rm -rf $REPO_DIR

# %%
git.Repo.clone_from(os.environ["CLONE_FROM"], os.environ["REPO_DIR"])
# Out:
# <git.repo.base.Repo '/content/drive/MyDrive/StanfordLLM/thought-distillation/thought-distillation/.git'>

# %%
os.chdir(os.environ["REPO_DIR"] + "/source/main/py")

# %% [markdown]
# # Vector database

# %% [markdown]
# ### Instantiate

# %%
from vector_db import PineconeDb

# %%
pinecone_db = PineconeDb(index_name="quickstart")

# %%
pinecone_db.db_init(is_create=True)

# %% [markdown]
# ### Load FAQ

# %%
from domain_info import FaqData

faqs = FaqData().get_faq()
# Out:
# Cliq FAQs for use cases.xlsx
# HDFC CVP FAQs.xlsx
# PVA HDFC Referral FAQs test.xlsx
# PVA Titan FAQs.xlsx
# PVA TNGC FAQs for Croma.xlsx
# PVA Qmin FAQs.xlsx
# PVA_BGC_Tanishq_FAQs.xlsx
# PVA Qik FAQs (2).xlsx
# PVA_BGC_Titan_Eye_Plus_FAQs.xlsx
# PVA HDFC FAQs.xlsx
# PVA HDFC Updated FAQs.xlsx
# PVA Qik FAQs.xlsx
# PVA Bill Payments FAQs New.xlsx
# UPI FAQs master sheet.xlsx
# PVA Super Top up Insurance FAQs.xlsx
# PVA AAI Updated FAQs.xlsx
# PVA TataPay FAQs.xlsx
# PVA Westside FAQs.xlsx
# PVA Tata1mg FAQs.xlsx
# PVA IHCL FAQs.xlsx
# PVA ZipCare Extended Warranty FAQs.xlsx
# PVA Qik Updated FAQs.xlsx
# UPI FAQ.xlsx
# PVA Cultfit FAQs.xlsx
# Sample PVA DG FAQs.xlsx
# PVA Cliq FAQs.xlsx
# IPL Neupass FAQs.xlsx
# UPI new FAQs.xlsx
# PVA TNGC FAQs for Hotel.xlsx
# PVA_BGC_MasterList_FAQs_v2.xlsx
# KnowledgeBaseReplica.xlsx
# PVA HDFC FAQs (2).xlsx
# PVA TataPlay FAQs.xlsx
# IIFL_FAQs.xlsx
# PVA_BGC_FAQs.xlsx
# PVA BB FAQs.xlsx
# PVA AAI FAQs.xlsx
# PVA Qik PL Updated FAQs.xlsx
# PVA TNGC FAQs for BB.xlsx
# PVA DG FAQs.xlsx
# PVA Tata Pay Later FAQs.xlsx
# TCap_FAQsV1.xlsx
# PVA HDFC Referral FAQs.xlsx
# PVA Croma FAQs.xlsx
# Bill Payments FAQ.xlsx

# %%
faqs
# Out:
# [{'user_question': 'How do I find invoices for my past orders?',
#   'agent_answer': "Don't worry, a copy of your invoice will be emailed to your registered email ID. You can also visit 'Order History' in the 'My Account' section of the Tata CliQ app to find a copy of your invoice.",
#   'source': 'Cliq FAQs for use cases.xlsx',
#   'row': 0},
#  {'user_question': 'How will I know that my refund has been initiated?',
#   'agent_answer': 'You never have to worry about that. Tata CLiQ will send you an SMS and email confirming the initiation of your refund. Your refund should reach you within 3-4 working days. In the case of CLiQ Cash refund, the same will be processed in one business day.',
#   'source': 'Cliq FAQs for use cases.xlsx',
#   'row': 1},
#  {'user_question': 'I still haven’t got my refund. Why?',
#   'agent_answer': 'If you’ve received a confirmation on the approval of your refund, you will definitely get it. However, in rare cases, there are technical difficulties that can delay refund transfers. If the wait seems too long, you can always contact the Tata CLiQ Customer Care team for support.',
#   'source': 'Cliq FAQs for use cases.xlsx',
#   'row': 2},
#  {'user_question': 'Am I eligible for the Tata NeuCard?',
#   'agent_answer': 'The Tata Neu HDFC Bank Credit Card is a Co-branded credit card launched in partnership with HDFC Bank. Currently, this is an invite-only programme on Tata Neu. It will be made available for all Tata Neu customers very soon.\n•\tThe applicant must be a Salaried Professional, Self-Employed Professional or Self-Employed Businessperson.\n•\tExisting HDFC Bank Credit Card holders can also apply for this Card. The Credit Limit of existing HDFC Bank Credit Card will be shared with the Tata Neu HDFC Bank Credit Card.\nEligibility condition for salaried customers:\n1.\tAge group: 21-60 years\n2.\tGross Monthly Income > ₹ 25,000 for Tata Neu Plus HDFC Bank Credit Card.\n3.\tGross Monthly Income > ₹ 100,000 for Tata Neu Infinity HDFC Bank Credit Card.\n\nEligibility condition for self-employed customers:\n1.\tAge group: 21-65 years\n2.\tLast year ITR > ₹ 6 Lakhs per annum for Tata Neu Plus HDFC Bank Credit Card.\n3.\tLast year ITR > ₹ 12 Lakhs per annum for Tata Neu Infinity HDFC Bank Credit Card.',
#   'source': 'HDFC CVP FAQs.xlsx',
#   'row': 0},
#  {'user_question': 'What is the Tata Neu HDFC Bank Credit Card application completion window?',
#   'agent_answer': 'Your Tata Neu HDFC Bank Credit Card application once initiated must be completed within 10 days from the application start date.',
#   'source': 'HDFC CVP FAQs.xlsx',
#   'row': 1},
#  {'user_question': 'I am an existing HDFC card holder can I apply for this card?',
#   'agent_answer': 'Existing HDFC Bank Credit Card holders can also apply for this Card. The Credit Limit of    existing HDFC Bank Credit Card will be shared with the Tata Neu HDFC Bank Credit Card.',
#   'source': 'HDFC CVP FAQs.xlsx',
#   'row': 2},
#  {'user_question': 'How do I earn NeuCoins on my Tata Neu HDFC Bank Credit Card purchases?',
#   'agent_answer': 'BAC-Key: #NeuCoinsEarnTable.qna-257',
#   'source': 'HDFC CVP FAQs.xlsx',
#   'row': 3},
#  {'user_question': 'Where can I use my NeuCoins?',
#   'agent_answer': 'BAC-Key: #NeuCoinsEarnTable.qna-258',
#   'source': 'HDFC CVP FAQs.xlsx',
#   'row': 4},
#  {'user_question': 'Neu Card referral program',
#   'agent_answer': "Under the NeuCard Refer and earn, the existing Tata Neu HDFC Bank Credit card holders (known as 'referrer') can refer their friends & family to apply for NeuCard & get ₹500/- (per Successful Referral), credited to their bigbasket wallet within 90 days from the date of successful card issuance of the referee.\xa0",
#   'source': 'PVA HDFC Referral FAQs test.xlsx',
#   'row': 0},
#  {'user_question': 'Credit Card referral program',
#   'agent_answer': "Under the NeuCard Refer and earn, the existing Tata Neu HDFC Bank Credit card holders (known as 'referrer') can refer their friends & family to apply for NeuCard & get ₹500/- (per Successful Referral), credited to their bigbasket wallet within 90 days from the date of successful card issuance of the referee.\xa0",
#   'source': 'PVA HDFC Referral FAQs test.xlsx',
#   'row': 1},
#  {'user_question': 'Neucard referral',
#   'agent_answer': "Under the NeuCard Refer and earn, the existing Tata Neu HDFC Bank Credit card holders (known as 'referrer') can refer their friends & family to apply for NeuCard & get ₹500/- (per Successful Referral), credited to their bigbasket wallet within 90 days from the date of successful card issuance of the referee.\xa0",
#   'source': 'PVA HDFC Referral FAQs test.xlsx',
#   'row': 2},
#  {'user_question': 'Neu card referral',
#   'agent_answer': "Under the NeuCard Refer and earn, the existing Tata Neu HDFC Bank Credit card holders (known as 'referrer') can refer their friends & family to apply for NeuCard & get ₹500/- (per Successful Referral), credited to their bigbasket wallet within 90 days from the date of successful card issuance of the referee.\xa0",
#   'source': 'PVA HDFC Referral FAQs test.xlsx',
#   'row': 3},
#  {'user_question': 'What is credit card referral program',
#   'agent_answer': "Under the NeuCard Refer and earn, the existing Tata Neu HDFC Bank Credit card holders (known as 'referrer') can refer their friends & family to apply for NeuCard & get ₹500/- (per Successful Referral), credited to their bigbasket wallet within 90 days from the date of successful card issuance of the referee.\xa0",
#   'source': 'PVA HDFC Referral FAQs test.xlsx',
#   'row': 4},
#  {'user_question': 'referral program',
#   'agent_answer': "Under the NeuCard Refer and earn, the existing Tata Neu HDFC Bank Credit card holders (known as 'referrer') can refer their friends & family to apply for NeuCard & get ₹500/- (per Successful Referral), credited to their bigbasket wallet within 90 days from the date of successful card issuance of the referee.\xa0",
#   'source': 'PVA HDFC Referral FAQs test.xlsx',
#   'row': 5},
#  {'user_question': 'What is Neucard referral program',
#   'agent_answer': "Under the NeuCard Refer and earn, the existing Tata Neu HDFC Bank Credit card holders (known as 'referrer') can refer their friends & family to apply for NeuCard & get ₹500/- (per Successful Referral), credited to their bigbasket wallet within 90 days from the date of successful card issuance of the referee.\xa0",
#   'source': 'PVA HDFC Referral FAQs test.xlsx',
#   'row': 6},
#  {'user_question': 'Tata Neu HDFC bank Credit Card referral program',
#   'agent_answer': "Under the NeuCard Refer and earn, the existing Tata Neu HDFC Bank Credit card holders (known as 'referrer') can refer their friends & family to apply for NeuCard & get ₹500/- (per Successful Referral), credited to their bigbasket wallet within 90 days from the date of successful card issuance of the referee.\xa0",
#   'source': 'PVA HDFC Referral FAQs test.xlsx',
#   'row': 7},
#  {'user_question': 'Tata Neu Credit Card referral program',
#   'agent_answer': "Under the NeuCard Refer and earn, the existing Tata Neu HDFC Bank Credit card holders (known as 'referrer') can refer their friends & family to apply for NeuCard & get ₹500/- (per Successful Referral), credited to their bigbasket wallet within 90 days from the date of successful card issuance of the referee.\xa0",
#   'source': 'PVA HDFC Referral FAQs test.xlsx',
#   'row': 8},
#  {'user_question': 'HDFC Credit Card referral program',
#   'agent_answer': "Under the NeuCard Refer and earn, the existing Tata Neu HDFC Bank Credit card holders (known as 'referrer') can refer their friends & family to apply for NeuCard & get ₹500/- (per Successful Referral), credited to their bigbasket wallet within 90 days from the date of successful card issuance of the referee.\xa0",
#   'source': 'PVA HDFC Referral FAQs test.xlsx',
#   'row': 9},
#  {'user_question': 'HDFC Credit Card referral',
#   'agent_answer': "Under the NeuCard Refer and earn, the existing Tata Neu HDFC Bank Credit card holders (known as 'referrer') can refer their friends & family to apply for NeuCard & get ₹500/- (per Successful Referral), credited to their bigbasket wallet within 90 days from the date of successful card issuance of the referee.\xa0",
#   'source': 'PVA HDFC Referral FAQs test.xlsx',
#   'row': 10},
#  {'user_question': 'Credit Card referral',
#   'agent_answer': "Under the NeuCard Refer and earn, the existing Tata Neu HDFC Bank Credit card holders (known as 'referrer') can refer their friends & family to apply for NeuCard & get ₹500/- (per Successful Referral), credited to their bigbasket wallet within 90 days from the date of successful card issuance of the referee.\xa0",
#   'source': 'PVA HDFC Referral FAQs test.xlsx',
#   'row': 11},
#  {'user_question': 'NeuCard Referral Program',
#   'agent_answer': "Under the NeuCard Refer and earn, the existing Tata Neu HDFC Bank Credit card holders (known as 'referrer') can refer their friends & family to apply for NeuCard & get ₹500/- (per Successful Referral), credited to their bigbasket wallet within 90 days from the date of successful card issuance of the referee.\xa0",
#   'source': 'PVA HDFC Referral FAQs test.xlsx',
#   'row': 12},
#  {'user_question': 'What kind of rewards can you earn through the NeuCard referral program?',
#   'agent_answer': "Under the NeuCard Refer and earn, the existing Tata Neu HDFC Bank Credit card holders (known as 'referrer') can refer their friends & family to apply for NeuCard & get ₹500/- (per Successful Referral), credited to their bigbasket wallet within 90 days from the date of successful card issuance of the referee.\xa0",
#   'source': 'PVA HDFC Referral FAQs test.xlsx',
#   'row': 13},
#  {'user_question': 'How does NeuCard Refer and earn work?',
#   'agent_answer': "Under the NeuCard Refer and earn, the existing Tata Neu HDFC Bank Credit card holders (known as 'referrer') can refer their friends & family to apply for NeuCard & get ₹500/- (per Successful Referral), credited to their bigbasket wallet within 90 days from the date of successful card issuance of the referee.\xa0",
#   'source': 'PVA HDFC Referral FAQs test.xlsx',
#   'row': 14},
#  {'user_question': 'How do you sign up for the NeuCard referral program?',
#   'agent_answer': "Under the NeuCard Refer and earn, the existing Tata Neu HDFC Bank Credit card holders (known as 'referrer') can refer their friends & family to apply for NeuCard & get ₹500/- (per Successful Referral), credited to their bigbasket wallet within 90 days from the date of successful card issuance of the referee.\xa0",
#   'source': 'PVA HDFC Referral FAQs test.xlsx',
#   'row': 15},
#  {'user_question': 'Are there any requirements or conditions for participating in the NeuCard referral program?',
#   'agent_answer': "Under the NeuCard Refer and earn, the existing Tata Neu HDFC Bank Credit card holders (known as 'referrer') can refer their friends & family to apply for NeuCard & get ₹500/- (per Successful Referral), credited to their bigbasket wallet within 90 days from the date of successful card issuance of the referee.\xa0",
#   'source': 'PVA HDFC Referral FAQs test.xlsx',
#   'row': 16},
#  {'user_question': 'Can you explain the benefits of the Tata Neu credit card referral program?',
#   'agent_answer': "Under the NeuCard Refer and earn, the existing Tata Neu HDFC Bank Credit card holders (known as 'referrer') can refer their friends & family to apply for NeuCard & get ₹500/- (per Successful Referral), credited to their bigbasket wallet within 90 days from the date of successful card issuance of the referee.\xa0",
#   'source': 'PVA HDFC Referral FAQs test.xlsx',
#   'row': 17},
#  {'user_question': 'Can I participate in the Tata Neu credit card referral program if I am not a Tata Neu credit cardholder myself?',
#   'agent_answer': "Under the NeuCard Refer and earn, the existing Tata Neu HDFC Bank Credit card holders (known as 'referrer') can refer their friends & family to apply for NeuCard & get ₹500/- (per Successful Referral), credited to their bigbasket wallet within 90 days from the date of successful card issuance of the referee.\xa0",
#   'source': 'PVA HDFC Referral FAQs test.xlsx',
#   'row': 18},
#  {'user_question': 'Can I participate in the Neu card referral program if I am not a Tata Neu credit cardholder myself?',
#   'agent_answer': "Under the NeuCard Refer and earn, the existing Tata Neu HDFC Bank Credit card holders (known as 'referrer') can refer their friends & family to apply for NeuCard & get ₹500/- (per Successful Referral), credited to their bigbasket wallet within 90 days from the date of successful card issuance of the referee.\xa0",
#   'source': 'PVA HDFC Referral FAQs test.xlsx',
#   'row': 19},
#  {'user_question': 'Can I participate in the credit card referral program if I am not a Tata Neu credit cardholder myself?',
#   'agent_answer': "Under the NeuCard Refer and earn, the existing Tata Neu HDFC Bank Credit card holders (known as 'referrer') can refer their friends & family to apply for NeuCard & get ₹500/- (per Successful Referral), credited to their bigbasket wallet within 90 days from the date of successful card issuance of the referee.\xa0",
#   'source': 'PVA HDFC Referral FAQs test.xlsx',
#   'row': 20},
#  {'user_question': 'Can you explain the benefits of the Neu card referral program?',
#   'agent_answer': "Under the NeuCard Refer and earn, the existing Tata Neu HDFC Bank Credit card holders (known as 'referrer') can refer their friends & family to apply for NeuCard & get ₹500/- (per Successful Referral), credited to their bigbasket wallet within 90 days from the date of successful card issuance of the referee.\xa0",
#   'source': 'PVA HDFC Referral FAQs test.xlsx',
#   'row': 21},
#  {'user_question': 'Can you explain the benefits of the credit card referral program?',
#   'agent_answer': "Under the NeuCard Refer and earn, the existing Tata Neu HDFC Bank Credit card holders (known as 'referrer') can refer their friends & family to apply for NeuCard & get ₹500/- (per Successful Referral), credited to their bigbasket wallet within 90 days from the date of successful card issuance of the referee.\xa0",
#   'source': 'PVA HDFC Referral FAQs test.xlsx',
#   'row': 22},
#  {'user_question': 'Is there any referral program for NeuCard',
#   'agent_answer': "Under the NeuCard Refer and earn, the existing Tata Neu HDFC Bank Credit card holders (known as 'referrer') can refer their friends & family to apply for NeuCard & get ₹500/- (per Successful Referral), credited to their bigbasket wallet within 90 days from the date of successful card issuance of the referee.\xa0",
#   'source': 'PVA HDFC Referral FAQs test.xlsx',
#   'row': 23},
#  {'user_question': 'How do I refer someone to NeuCard?\xa0',
#   'agent_answer': 'NeuCard customers can share their referral link/code with their family or friends through SMS, Email, WhatsApp and other social media channels.\xa0',
#   'source': 'PVA HDFC Referral FAQs test.xlsx',
#   'row': 24},
#  {'user_question': 'What are the steps involved in referring someone to NeuCard?',
#   'agent_answer': 'NeuCard customers can share their referral link/code with their family or friends through SMS, Email, WhatsApp and other social media channels.\xa0',
#   'source': 'PVA HDFC Referral FAQs test.xlsx',
#   'row': 25},
#  {'user_question': 'Can you guide me through the process of referring someone to NeuCard?',
#   'agent_answer': 'NeuCard customers can share their referral link/code with their family or friends through SMS, Email, WhatsApp and other social media channels.\xa0',
#   'source': 'PVA HDFC Referral FAQs test.xlsx',
#   'row': 26},
#  {'user_question': 'Is there a specific way to refer someone to NeuCard?',
#   'agent_answer': 'NeuCard customers can share their referral link/code with their family or friends through SMS, Email, WhatsApp and other social media channels.\xa0',
#   'source': 'PVA HDFC Referral FAQs test.xlsx',
#   'row': 27},
#  {'user_question': 'How to refer Someone for Credit Card?',
#   'agent_answer': 'NeuCard customers can share their referral link/code with their family or friends through SMS, Email, WhatsApp and other social media channels.\xa0',
#   'source': 'PVA HDFC Referral FAQs test.xlsx',
#   'row': 28},
#  {'user_question': 'How to refer Someone for Neu Card?',
#   'agent_answer': 'NeuCard customers can share their referral link/code with their family or friends through SMS, Email, WhatsApp and other social media channels.\xa0',
#   'source': 'PVA HDFC Referral FAQs test.xlsx',
#   'row': 29},
#  {'user_question': 'How to refer Someone for NeuCard?',
#   'agent_answer': 'NeuCard customers can share their referral link/code with their family or friends through SMS, Email, WhatsApp and other social media channels.\xa0',
#   'source': 'PVA HDFC Referral FAQs test.xlsx',
#   'row': 30},
#  {'user_question': 'How to refer Someone for CC?',
#   'agent_answer': 'NeuCard customers can share their referral link/code with their family or friends through SMS, Email, WhatsApp and other social media channels.\xa0',
#   'source': 'PVA HDFC Referral FAQs test.xlsx',
#   'row': 31},
#  {'user_question': 'Referral process for CC',
#   'agent_answer': 'NeuCard customers can share their referral link/code with their family or friends through SMS, Email, WhatsApp and other social media channels.\xa0',
#   'source': 'PVA HDFC Referral FAQs test.xlsx',
#   'row': 32},
#  {'user_question': 'Referral process for Credit Card',
#   'agent_answer': 'NeuCard customers can share their referral link/code with their family or friends through SMS, Email, WhatsApp and other social media channels.\xa0',
#   'source': 'PVA HDFC Referral FAQs test.xlsx',
#   'row': 33},
#  {'user_question': 'Referral process for Neu Card',
#   'agent_answer': 'NeuCard customers can share their referral link/code with their family or friends through SMS, Email, WhatsApp and other social media channels.\xa0',
#   'source': 'PVA HDFC Referral FAQs test.xlsx',
#   'row': 34},
#  {'user_question': 'Referral process for NeuCard',
#   'agent_answer': 'NeuCard customers can share their referral link/code with their family or friends through SMS, Email, WhatsApp and other social media channels.\xa0',
#   'source': 'PVA HDFC Referral FAQs test.xlsx',
#   'row': 35},
#  {'user_question': 'Referral process for Tata Neu HDFC bank credit card',
#   'agent_answer': 'NeuCard customers can share their referral link/code with their family or friends through SMS, Email, WhatsApp and other social media channels.\xa0',
#   'source': 'PVA HDFC Referral FAQs test.xlsx',
#   'row': 36},
#  {'user_question': 'How can I share referral link with family',
#   'agent_answer': 'NeuCard customers can share their referral link/code with their family or friends through SMS, Email, WhatsApp and other social media channels.\xa0',
#   'source': 'PVA HDFC Referral FAQs test.xlsx',
#   'row': 37},
#  {'user_question': 'How can I share referral link with friend',
#   'agent_answer': 'NeuCard customers can share their referral link/code with their family or friends through SMS, Email, WhatsApp and other social media channels.\xa0',
#   'source': 'PVA HDFC Referral FAQs test.xlsx',
#   'row': 38},
#  {'user_question': 'How can I share referral code with friend',
#   'agent_answer': 'NeuCard customers can share their referral link/code with their family or friends through SMS, Email, WhatsApp and other social media channels.\xa0',
#   'source': 'PVA HDFC Referral FAQs test.xlsx',
#   'row': 39},
#  {'user_question': 'How can I share referral code with Family',
#   'agent_answer': 'NeuCard customers can share their referral link/code with their family or friends through SMS, Email, WhatsApp and other social media channels.\xa0',
#   'source': 'PVA HDFC Referral FAQs test.xlsx',
#   'row': 40},
#  {'user_question': 'How many referrals can I make?\xa0',
#   'agent_answer': 'There is no limit to the number of referrals. However,\u202feligible customers can earn\u202frewards with a maximum earning of\u202f₹50,000\u202ffor 100 successful referrals in a calendar month. \xa0',
#   'source': 'PVA HDFC Referral FAQs test.xlsx',
#   'row': 41},
#  {'user_question': 'Is there a limit to the number of referrals I can make?',
#   'agent_answer': 'There is no limit to the number of referrals. However,\u202feligible customers can earn\u202frewards with a maximum earning of\u202f₹50,000\u202ffor 100 successful referrals in a calendar month. \xa0',
#   'source': 'PVA HDFC Referral FAQs test.xlsx',
#   'row': 42},
#  {'user_question': 'How do I make my smartwatch compatible with my smartphone?',
#   'agent_answer': "That's easy! Fastrack has smartwatches that are compatible with Android and iOS phones. So, compatibility will not be an issue.",
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 0},
#  {'user_question': "How do I know if warranty's available on a specific watch?",
#   'agent_answer': "Don't worry. You will get the warranty card with every purchase. For a specifc product, you can check the product's warranty to know more.",
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 1},
#  {'user_question': 'Can I return, exchange or cancel my order?',
#   'agent_answer': "Yes, of course. Fastrack is very accommodating when it comes to cancellations or returns. However, make sure to cancel the delivery before it gets shipped. In case you want to return the product, ensure that it's unused and in its original packing. The refund will be processed once the product is collected from your address.",
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 2},
#  {'user_question': 'What do we get inside the box of the Reflex 3.0 smart band from Fastrack?',
#   'agent_answer': 'You will find the Reflex 3.0 smart band with a charging cable and a quick start guide, inside the box.',
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 3},
#  {'user_question': 'Do I need to download an app to pair the Reflex 3.0?',
#   'agent_answer': "Yes, you have to download the 'Fastrack Reflex World' app to pair your smart band with your smartphone.",
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 4},
#  {'user_question': 'What is the cancellation policy at Fastrack?',
#   'agent_answer': "If you've successfully placed your order online but want to cancel it, you can do it before the order is shipped. You can easily monitor all your orders on Tata Neu and find out where they are in the shipping process. After placing the cancellation request online, we start the refund process.",
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 5},
#  {'user_question': 'How can I check my orders?',
#   'agent_answer': "You can easily find your orders in the 'My order' section on the top left menu bar on the Titan page. You can also ask for help from our dedicated Customer Care team via call or chat. An update will be sent to your registered mobile number with the tracking details of your order once it has been dispatched.",
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 6},
#  {'user_question': 'How often should I service my watches?',
#   'agent_answer': 'Watches of all kinds require regular servicing and maintenance. Regular servicing ensures longevity so that your watch keeps running smoothly. It is recommended that you get your watches serviced every four-six months.',
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 7},
#  {'user_question': 'Can I replace my order after I receive the product?',
#   'agent_answer': 'If you wish to replace your product after delivery, you can contact our Customer Care and give a valid reason for your requesting replacement. We will then arrange for a pick-up and refund.',
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 8},
#  {'user_question': 'Do I have to change my watch batteries often?',
#   'agent_answer': 'Usually, your watch battery should last you 2-5 years. The longevity of quartz batteries depends on the type of watch and the amount of energy required for it to function.',
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 9},
#  {'user_question': 'Do you customise wedding watches for men?',
#   'agent_answer': 'Yes, we do! You can customise wedding watches for men when you buy them from premium brands like Titan, which offers engraving features on wedding watches.',
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 10},
#  {'user_question': 'What happens if my order is lost in transit?',
#   'agent_answer': 'In the unlikely event that your order gets lost during transit, we wait for 15 days to track your lost order and if we are still unsuccessful, then we process your refund to the original mode of payment.',
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 11},
#  {'user_question': 'Which locations in India do you deliver to?',
#   'agent_answer': 'Currently, we deliver to selected cities within India. Check if we deliver to your pin code or city by entering your pin code at the checkout page.',
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 12},
#  {'user_question': 'Can I order something to be delivered in India even if I don’t live in the country?\n',
#   'agent_answer': 'Yes, you can place an order from outside of India as long as you provide a valid shipping address within India. Also, note that we deliver only to selected cities within India. To check whether we deliver to your desired area or city, enter your pin code at the checkout page.',
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 13},
#  {'user_question': 'Do I need to pay shipping or delivery charges?',
#   'agent_answer': 'No, there are no shipping or delivery charges.',
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 14},
#  {'user_question': 'How long does it typically take to receive an order?',
#   'agent_answer': 'The time taken for delivery tends to vary according to the destination. However, we try our best to ensure that the order is delivered within 5-7 working days of you placing the order.',
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 15},
#  {'user_question': 'How can I know the status of my order?',
#   'agent_answer': 'It’s easy! You can track your orders by clicking on Track order on the top left menu.',
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 16},
#  {'user_question': 'What do I do if I receive the wrong product?',
#   'agent_answer': "In the unlikely event that you receive the wrong product, you can call us at 1800 20 8282 638 or write to customercare@tataneu.com to report it and cancel the order. In case you want to return the product, ensure that it's unused and in its original packing. The refund will be processed once the product is collected from your address.",
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 17},
#  {'user_question': 'What do I do if I receive a damaged product?',
#   'agent_answer': 'In the unlikely event that you receive a damaged product, you can return the product unused and in the same condition as you received it, in its original packaging, along with the invoice for a refund. We will arrange for the order to be collected from the provided address through our logistic partner and returned to us. Do make sure to call us at 1800-20-8282-638 or write to customercare@tataneu.com within 7 days of receipt of the product to report the incident.\n',
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 18},
#  {'user_question': 'Can I return the product bought from Tata Neu at any Titan company physical store?',
#   'agent_answer': 'No, you can’t return products bought from Tata Neu app or website at any Titan company physical store. You can raise an online request. ',
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 19},
#  {'user_question': 'What is the exchange policy?',
#   'agent_answer': 'Our policy doesn’t allow us to exchange any product.',
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 20},
#  {'user_question': 'Do you deliver Titan products to international locations?',
#   'agent_answer': 'No, unfortunately, we do not ship Titan products to international locations, yet.',
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 21},
#  {'user_question': 'What is Tanishq Digital Gold?',
#   'agent_answer': 'Tanishq Digital Gold is an organised and transparent method of buying 24 carat gold in compliance with all applicable laws and regulations, brought to you by Tanishq, and powered by SafeGold. ',
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 22},
#  {'user_question': 'What is SafeGold?',
#   'agent_answer': 'SafeGold is a product of Digital Gold India Private Limited- an institutionally owned company, where the World Gold Council is a minority investor (through World Gold Council (India) Private Limited).',
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 23},
#  {'user_question': 'What is the purity of gold offered through Tanishq Digital Gold?',
#   'agent_answer': 'Tanishq Digital Gold offers 24 Karat Gold of 995 fineness (99.5% pure) or higher. SafeGold, on behalf of Tanishq Digital Gold, sources LBMA “good delivery” bars from trusted sources for the digital gold offered to you.',
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 24},
#  {'user_question': 'Why is the SafeGold buy price different from the SafeGold sell price?',
#   'agent_answer': 'Tanishq Digital Gold offers international grade bullion from institutional suppliers. When you resell gold to us, we sell it back to institutional participants in the wholesale bullion market, where the buyback rate is lower than the selling rate – this is referred to as the buy-sell spread.\nIn addition to the buy-sell spread in the commercial bullion market, GST is added to the buy price, but it is not levied on any sell transactions. Further, there are charges incurred on the payment gateway, trustee, insurance and custodian fees which also contribute to the difference in buy and sell price.',
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 25},
#  {'user_question': 'Is there a minimum lock-in period to buy digital gold?',
#   'agent_answer': 'No, there is no minimum lock-in period. You are free to make a one-time purchase of digital gold, without being obligated to make any fixed or periodic payments. Alternatively, you can also sign up for a Gold Savings Instalment Plan (Gold SIP).',
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 26},
#  {'user_question': 'What will happen to the gold associated with accumulations in my account, in the unlikely event of SafeGold being liquidated?',
#   'agent_answer': 'The gold associated with the accumulations in your account is separate from the other assets of SafeGold. IDBI Trusteeship Services Limited, an independent trustee, acts for and on your behalf. The gold purchased by the Company associated with the accumulations in your accounts is held with the custodian. When you ask for delivery, the requisite quantity of gold will be removed from the custodian and delivered to you through a reputed courier service. Since the security trustee has a charge over the gold, any unlikely adverse event faced by the Company will not affect the gold associated with the accumulations in your account. Further, the title of the gold clearly rests with you and the physical gold stored with the custodian on account of SafeGold customers is not an asset of SafeGold in any way.',
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 27},
#  {'user_question': 'What is the minimum & maximum amount I can purchase through Tanishq Digital Gold?',
#   'agent_answer': 'Subject to the completion of KYC verification of your account, the minimum amount of purchase is Rs.100. There is no maximum amount or limit to how much you can purchase. ',
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 28},
#  {'user_question': 'How do I sell my gold?',
#   'agent_answer': 'Tanishq Digital Gold provides a live sell price quote. You can choose to sell any amount starting with a minimum of Rs.100 to a maximum of the amount of gold that you own. The sell quote may be temporarily unavailable in the unlikely event of a disruption in the bullion market.',
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 29},
#  {'user_question': 'What is the price of the gold sold or bought from me?',
#   'agent_answer': 'Tanishq Digital Gold will provide a live buy-sell quote for you, which will be derived from the wholesale bullion market plus a commission to cover operating costs. The actual purchase price paid by you will always be transparently published so that you have a chance to compare with all other sources before entering into a transaction.',
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 30},
#  {'user_question': 'Is the gold associated with my accumulations kept in safe custody?',
#   'agent_answer': "The gold purchased on your behalf is stored with Brink's, the leading safe keeper of precious metals across the world. The gold is insured, both for storage and transit when being delivered to you. Further, IDBI Trusteeship has a charge on all gold stored in the vault in your favour. This ensures that your gold is protected at all times regardless of any external events.",
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 31},
#  {'user_question': 'Who will insure the physical vault?',
#   'agent_answer': "The secure storage provider (Brink's) has a comprehensive, global insurance policy that includes the insurance cover on your gold stored in their vaults. In addition, SafeGold has an additional insurance policy to cover gold in transit.",
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 32},
#  {'user_question': 'What is the maximum time period for which my gold can be stored with SafeGold?',
#   'agent_answer': 'You can store your gold with SafeGold for a period of 10 years from the date of purchase. The custody shall be without charge for the first 5 years, and thereafter, will continue to be stored by SafeGold for a nominal fee to cover storage costs. You will be intimated in advance of being charged the fee, and will have the option to sell or request delivery of your gold at all times.',
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 33},
#  {'user_question': 'Can I have a joint account for Tanishq Digital Gold?',
#   'agent_answer': 'No, you cannot have a joint account for Tanishq Digital Gold.',
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 34},
#  {'user_question': 'Can I cancel my sell order or request of gold sell?',
#   'agent_answer': 'No, you cannot cancel the order once it has been successfully placed on the platform.',
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 35},
#  {'user_question': 'What if I die during the tenure of the plan?',
#   'agent_answer': 'In the event of your death, as per the process specifically allowed by Tanishq Digital Gold, and subject to the required due diligence, the title to your gold lying in the vault and your account shall be transferred to your legal heir.',
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 36},
#  {'user_question': 'Is it possible to store my withdrawn gold coins in safe custody and have them delivered later?',
#   'agent_answer': 'Once you place a delivery request, you will need to accept the delivery made to you. It cannot be made at a later date.',
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 37},
#  {'user_question': 'Can I change my delivery address once I have placed a delivery request?',
#   'agent_answer': 'No, your address on the delivery request, once accepted on the platform, cannot be changed.',
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 38},
#  {'user_question': 'Can someone else redeem the physical gold coins on my behalf?',
#   'agent_answer': 'No, only you can request for the delivery of physical coins from your SafeGold balance. However, in the event of your death, your legal heir will be able to collect the gold coins by showing their proof of identity of along with the original or notarized copy of the death certificate and proof that the person is your legal heir.',
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 39},
#  {'user_question': 'How can I be assured that the gold coins delivered to me are genuine?',
#   'agent_answer': 'All our coins are assay certified for purity by government-licensed agencies, delivered in tamper proof packaging, and are dispatched directly from our premises. The coins are also insured through transit, and checked before delivery to avoid any risk of fraud. However, in case of any discrepancy, please get in touch with our Customer Care.',
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 40},
#  {'user_question': 'Can I exchange my digital gold balance at any other jewellery chain?',
#   'agent_answer': 'If you have purchased Tanishq Digital Gold, you can only exchange it for jewellery at Tanishq physical or online stores.',
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 41},
#  {'user_question': 'Can I exchange the digital gold I have purchased on other platforms at Tanishq stores as well?',
#   'agent_answer': 'If you have purchased SafeGold on any platform, you can exchange it for jewellery at Tanishq stores through the same process as mentioned above.',
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 42},
#  {'user_question': 'Is there any regulator or grievance redressal mechanism?',
#   'agent_answer': 'SafeGold is neither a Collective Investment Scheme nor a deposit. Thus, this plan doesn’t fall under the purview of SEBI or RBI, and there is no regulator for this product offering. To ensure that your interest is of foremost importance, a security trustee has been appointed for SafeGold. For any grievances specifically in relation to your gold purchase and related transactions, you can approach the security trustee.',
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 43},
#  {'user_question': 'Does Taneira have gift cards?',
#   'agent_answer': 'Yes, Taneira does have gift cards. The value can be redeemed in physical or online stores.',
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 44},
#  {'user_question': 'What is your delivery timeline?',
#   'agent_answer': 'It takes 7 working days from the day of order confirmation to deliver the products across India.',
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 45},
#  {'user_question': 'What’s your return policy for online orders?',
#   'agent_answer': 'We have 7-days return policy.\n\nIn the unlikely event that the order delivered is in damaged condition, or otherwise, you can return the product unused and in the same condition as you received it, in its original packaging, along with the invoice and get the refund. Our courier partner will collect the order from the address provided by you and will get it back to us.\n\nNote: Shipments returned through any other logistic partner will not be accepted.\nMake sure to provide the invoice or guarantee card in the package for the return process. Unfortunately, returns cannot be processed without these.',
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 46},
#  {'user_question': 'What is the refund structure?',
#   'agent_answer': 'If you choose to pay online, the amount will be refunded within 7-15 working days from the receipt of the returned products.\n\nIn case of Cash on Delivery (COD) where you’ve paid in cash once the product is received, the amount is refunded via online transfer using NEFT (National Electronic Fund Transfer). You will need to provide a cancelled cheque (or the bank details) along with the returned product in order to initiate the return process. It will take 7-15 working days for the amount to be credited in your bank account.',
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 47},
#  {'user_question': 'Will I earn NeuCoins on discounted products?',
#   'agent_answer': 'No, you will not earn any NeuCoins on discounted products.',
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 48},
#  {'user_question': 'For the Titan products I purchase on Tata Neu, how many days will it take for the NeuCoins to reflect in my account?',
#   'agent_answer': 'NeuCoins will be credited 15 days after the product is delivered.',
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 49},
#  {'user_question': 'How many NeuCoins will I earn on shopping for Titan Brands on Tata Neu?',
#   'agent_answer': 'You will earn NeuCoins on every Rs.100 spent across all tiers, on eligible product value. Here are the details:\nPlain gold jewellery : 0.6%\nStudded Jewellery : 2%\nNon-Jewellery : 5%',
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 50},
#  {'user_question': 'Will I earn NeuCoins if I shop at Titan stores?',
#   'agent_answer': 'No, unfortunately, you will not earn any NeuCoins on transactions done at Titan stores.',
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 51},
#  {'user_question': "Will I earn NeuCoins if I purchase from Titan's exclusive website?",
#   'agent_answer': "No, as of now, you will not earn any NeuCoins on transactions done at Titan's exclusive website.",
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 52},
#  {'user_question': 'Can I redeem NeuCoins at Titan stores?',
#   'agent_answer': 'No, unfortunately, you cannot redeem any NeuCoins on transactions done at Titan stores.',
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 53},
#  {'user_question': "Can I redeem NeuCoins if I purchase from Titan's exclusive website?",
#   'agent_answer': "No, unfortunately, you cannot redeem any NeuCoins on transactions done at Titan's exclusive website.",
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 54},
#  {'user_question': 'Will I earn Encircle points if I purchase from Tata Neu?',
#   'agent_answer': 'No, you will not earn any Encircle points on purchasing Titan products from Tata Neu.',
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 55},
#  {'user_question': 'Can I redeem Encircle points on Tata Neu?',
#   'agent_answer': 'Yes, you can redeem Encircle points on Tata Neu.',
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 56},
#  {'user_question': 'Will my Encircle Program Tier be upgraded when I shop from Tata Neu?',
#   'agent_answer': 'No, your Encircle Program Tier does not get updgraded on shopping at Tata Neu.',
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 57},
#  {'user_question': 'Can I redeem both Encircle Points and NeuCoins together?',
#   'agent_answer': "No, you cannot redeem both Encircle Points & NeuCoins together. If you have Encircle points, you'll need to use those first. Once you have exhausted all your Encircle Points, you are free to redeem your NeuCoins.",
#   'source': 'PVA Titan FAQs.xlsx',
#   'row': 58},
#  {'user_question': 'Where can I purchase a brand Gift card? ',
#   'agent_answer': 'You can purchase a Brand Gift Card for yourself and your loved ones on the Tata Neu App. Within Tata Neu,\ngo to Tata Pay -> Gift Cards. Click on ‘Buy a Gift Card’ and on top of the screen click on ‘change’ to render \nBrand Gift Card Options. You can choose your preferred gift card.',
#   'source': 'PVA TNGC FAQs for Croma.xlsx',
#   'row': 0},
#  {'user_question': 'How do I pay for brand Gift Card?',
#   'agent_answer': 'We support different modes of payment including credit cards, debit cards, UPI and internet banking.',
#   'source': 'PVA TNGC FAQs for Croma.xlsx',
#   'row': 1},
#  {'user_question': 'Are there any limitations to purchase brand gift card?',
#   'agent_answer': 'The minimum and maximum denomination that can be purchased per gift card is 100 and 5000 respectively.',
#   'source': 'PVA TNGC FAQs for Croma.xlsx',
#   'row': 2},
#  {'user_question': 'Can I extend the validity of a brand Gift Card?',
#   'agent_answer': 'Brand gift cards come with a fixed validity which cannot be extended. If you still have any concerns regarding the validity or expiry of a brand gift card, please reach out to the brand directly.',
#   'source': 'PVA TNGC FAQs for Croma.xlsx',
#   'row': 3},
#  {'user_question': 'What is the validity of a Branded Gift Card?',
#   'agent_answer': 'Validity of the Croma brand gift card is 365 days.',
#   'source': 'PVA TNGC FAQs for Croma.xlsx',
#   'row': 4},
#  {'user_question': 'I purchase a Brand Gift Card for someone, how do I resend it? ',
#   'agent_answer': 'Within the Tata Neu App, go to My Orders -> Gift Cards. Look for your order and select the Gift Card you want to\nresend. You will see an option of resending gift card in order page. You can also contact Tata Neu customer care at \non 1800 20 8282 638, 7AM to 12 midnight for further assistance. If the gift card is already redeemed, it cannot be resent.',
#   'source': 'PVA TNGC FAQs for Croma.xlsx',
#   'row': 5},
#  {'user_question': 'Are there any terms and conditions involved?',
#   'agent_answer': 'The terms and conditions for each brand Gift Card or E-Gift Card can differ, so review the terms and conditions and overall details before you choose a Gift Card. This will give you a very clear idea and help you with your decision.',
#   'source': 'PVA TNGC FAQs for Croma.xlsx',
#   'row': 6},
#  {'user_question': 'How do I redeem Croma Gift Card?',
#   'agent_answer': '• Visit the outlet near you.\n• Before making the purchase confirm about the acceptance of Gift Card at the store.\n• Choose the products you would like to buy.\n• Show your Gift Card details to the cashier at the time of billing & pay any balance amount by cash or card.\n• Croma Gift Cards can also be redeemed on Tata Neu or Croma.com',
#   'source': 'PVA TNGC FAQs for Croma.xlsx',
#   'row': 7},
#  {'user_question': 'Can I return a Brand Gift card?',
#   'agent_answer': 'Brand gift cards cannot be returned. Please check the refund policy at http://www.woohoo.in/faq for further details.',
#   'source': 'PVA TNGC FAQs for Croma.xlsx',
#   'row': 8},
#  {'user_question': 'How do I check my order of Brand Gift Card?',
#   'agent_answer': 'Within Tata Neu app, Go to My Orders -> Gift Card. You can see all the Gift Card orders placed by you.',
#   'source': 'PVA TNGC FAQs for Croma.xlsx',
#   'row': 9},
#  {'user_question': 'Will I earn NeuCoins for a Brand Gift Card purchase?',
#   'agent_answer': 'NeuCoins are not awarded for any Gift Card purchase.',
#   'source': 'PVA TNGC FAQs for Croma.xlsx',
#   'row': 10},
#  {'user_question': 'What is Qmin?',
#   'agent_answer': 'Qmin brings you Qurated Quality Quisine from our signature restaurants from Taj, SeleQtions, Vivanta hotels. We deliver your favourite dishes with utmost care.',
#   'source': 'PVA Qmin FAQs.xlsx',
#   'row': 0},
#  {'user_question': 'How does Qmin work?',
#   'agent_answer': "Enter the delivery location or PIN code to choose from available signature restaurants. Select your favourite dishes and complete the payment and we'll deliver them to you.",
#   'source': 'PVA Qmin FAQs.xlsx',
#   'row': 1},
#  {'user_question': 'From which restaurants can I order?',
#   'agent_answer': "Order food online from:\n\nMumbai:\nGolden Dragon, Masala Kraft, Souk and Shamiana from The Taj Mahal Palace\nVista, Ming Yang, and Masala Bay from Taj Lands End\nTrattoria, The Konkan Cafe, and Thai Pavilion from President, Mumbai - IHCL SeleQtions\nAnuka – Our newly launched menu  in Mumbai  serving comfort food\n\nDelhi:\nHouse of Ming and Machan from Taj Mahal\nSpicy Duck, Masala Art, Capital Kitchen from Taj Palace\nYellow Brick Road and Larry's China from Ambassador - IHCL SeleQtions\nIndus Express and Creo from Vivanta New Delhi Dwarka\nAnuka - Our newly launched menu  in Delhi serving comfort food\n\nBengaluru:\nBlue Ginger, Masala Klub and Machan from Taj West End\nTamarind and Soi & Sake from Taj Bangalore\nPalette and Paranda from Taj Yeshwantpur\nThe Trinity Square and Memories of China from Taj MG Road\nKaravalli and Mynt from Vivanta Bengaluru Residency Road\nLatitude and Terracotta from Vivanta Bengaluru Whitefield\n\nChennai:\nAnise, Golden Dragon and Southern Spice from Taj Coromandel\nRaintree and The Verandah from Taj Connemara\nMynt from Vivanta Chennai IT Expressway\nANUKA from Taj Madras Flight Kitchen Chennai\n\nKolkata:\nSonargaon, Chinnoiserie and Cal 27 from Taj Bengal\nMynt from Vivanta Kolkata\nANUKA from TajSATS Kolkata \n\nHyderabad: \nTaj Krishna, Hyderabad serving signatures from Golden Dragon, Firdaus, Encounters; Our newly launched menu serving comfort food\n\nOur Newly Launched Cities & Restaurants:\n\nTaj Swarna, Amritsar - Grand Trunk, The Chinese Room\nGinger Jamshedpur - Cafe Et Cetera\nGinger Bhubaneshwar - Cafe Et Cetera",
#   'source': 'PVA Qmin FAQs.xlsx',
#   'row': 2},
#  {'user_question': 'Can I place an order from a Taj, SeleQtions, Vivanta restaurant that is not listed on Qmin?',
#   'agent_answer': 'We will be delivering only from restaurants listed on the Qmin app. We are working on adding more of your favourite restaurants in destinations across India.',
#   'source': 'PVA Qmin FAQs.xlsx',
#   'row': 3},
#  {'user_question': 'Can I earn or redeem Taj InnerCircle points, Epicure points or Gift cards for orders placed on Qmin?',
# ...
#   'source': 'PVA HDFC FAQs.xlsx',
#   'row': 703},
#  {'user_question': 'Where can I check my Tata NeuCard CVV?',
#   'agent_answer': 'Steps to check the details of your Tata Neu HDFC Bank Credit Card:\\n1. Log in to the Tata Neu app & click on finance,\\n2. Go to the ‘Credit Cards’ section, then go to the dashboard,\\n3. Click on ‘view card details’,\\n4. You will be directed to the HDFC Bank page. Enter the OTP sent to your registered mobile no. to check your Tata Neu HDFC Bank Credit Card details.',
#   'source': 'PVA HDFC FAQs.xlsx',
#   'row': 704},
#  {'user_question': 'Where can I check my Tata NeuCard number?',
#   'agent_answer': 'Steps to check the details of your Tata Neu HDFC Bank Credit Card:\\n1. Log in to the Tata Neu app & click on finance,\\n2. Go to the ‘Credit Cards’ section, then go to the dashboard,\\n3. Click on ‘view card details’,\\n4. You will be directed to the HDFC Bank page. Enter the OTP sent to your registered mobile no. to check your Tata Neu HDFC Bank Credit Card details.',
#   'source': 'PVA HDFC FAQs.xlsx',
#   'row': 705},
#  {'user_question': 'Where can I check my Tata NeuCard expiry?',
#   'agent_answer': 'Steps to check the details of your Tata Neu HDFC Bank Credit Card:\\n1. Log in to the Tata Neu app & click on finance,\\n2. Go to the ‘Credit Cards’ section, then go to the dashboard,\\n3. Click on ‘view card details’,\\n4. You will be directed to the HDFC Bank page. Enter the OTP sent to your registered mobile no. to check your Tata Neu HDFC Bank Credit Card details.',
#   'source': 'PVA HDFC FAQs.xlsx',
#   'row': 706},
#  {'user_question': 'Where can I view my HDFC bank credit card details?',
#   'agent_answer': 'Steps to check the details of your Tata Neu HDFC Bank Credit Card:\\n1. Log in to the Tata Neu app & click on finance,\\n2. Go to the ‘Credit Cards’ section, then go to the dashboard,\\n3. Click on ‘view card details’,\\n4. You will be directed to the HDFC Bank page. Enter the OTP sent to your registered mobile no. to check your Tata Neu HDFC Bank Credit Card details.',
#   'source': 'PVA HDFC FAQs.xlsx',
#   'row': 707},
#  {'user_question': 'Where can I find my credit card number?',
#   'agent_answer': 'Steps to check the details of your Tata Neu HDFC Bank Credit Card:\\n1. Log in to the Tata Neu app & click on finance,\\n2. Go to the ‘Credit Cards’ section, then go to the dashboard,\\n3. Click on ‘view card details’,\\n4. You will be directed to the HDFC Bank page. Enter the OTP sent to your registered mobile no. to check your Tata Neu HDFC Bank Credit Card details.',
#   'source': 'PVA HDFC FAQs.xlsx',
#   'row': 708},
#  {'user_question': 'Where can I check my HDFC credit card number?',
#   'agent_answer': 'Steps to check the details of your Tata Neu HDFC Bank Credit Card:\\n1. Log in to the Tata Neu app & click on finance,\\n2. Go to the ‘Credit Cards’ section, then go to the dashboard,\\n3. Click on ‘view card details’,\\n4. You will be directed to the HDFC Bank page. Enter the OTP sent to your registered mobile no. to check your Tata Neu HDFC Bank Credit Card details.',
#   'source': 'PVA HDFC FAQs.xlsx',
#   'row': 709},
#  {'user_question': 'How can I view my HDFC Bank Credit card details?',
#   'agent_answer': 'Steps to check the details of your Tata Neu HDFC Bank Credit Card:\\n1. Log in to the Tata Neu app & click on finance,\\n2. Go to the ‘Credit Cards’ section, then go to the dashboard,\\n3. Click on ‘view card details’,\\n4. You will be directed to the HDFC Bank page. Enter the OTP sent to your registered mobile no. to check your Tata Neu HDFC Bank Credit Card details.',
#   'source': 'PVA HDFC FAQs.xlsx',
#   'row': 710},
#  {'user_question': 'How can I view my Tata Credit card details?',
#   'agent_answer': 'Steps to check the details of your Tata Neu HDFC Bank Credit Card:\\n1. Log in to the Tata Neu app & click on finance,\\n2. Go to the ‘Credit Cards’ section, then go to the dashboard,\\n3. Click on ‘view card details’,\\n4. You will be directed to the HDFC Bank page. Enter the OTP sent to your registered mobile no. to check your Tata Neu HDFC Bank Credit Card details.',
#   'source': 'PVA HDFC FAQs.xlsx',
#   'row': 711},
#  {'user_question': 'How can I check my HDFC Bank Credit card details?',
#   'agent_answer': 'Steps to check the details of your Tata Neu HDFC Bank Credit Card:\\n1. Log in to the Tata Neu app & click on finance,\\n2. Go to the ‘Credit Cards’ section, then go to the dashboard,\\n3. Click on ‘view card details’,\\n4. You will be directed to the HDFC Bank page. Enter the OTP sent to your registered mobile no. to check your Tata Neu HDFC Bank Credit Card details.',
#   'source': 'PVA HDFC FAQs.xlsx',
#   'row': 712},
#  {'user_question': 'How can I check my Tata Credit card details?',
#   'agent_answer': 'Steps to check the details of your Tata Neu HDFC Bank Credit Card:\\n1. Log in to the Tata Neu app & click on finance,\\n2. Go to the ‘Credit Cards’ section, then go to the dashboard,\\n3. Click on ‘view card details’,\\n4. You will be directed to the HDFC Bank page. Enter the OTP sent to your registered mobile no. to check your Tata Neu HDFC Bank Credit Card details.',
#   'source': 'PVA HDFC FAQs.xlsx',
#   'row': 713},
#  {'user_question': 'How can I check my Tata NeuCard details?',
#   'agent_answer': 'Steps to check the details of your Tata Neu HDFC Bank Credit Card:\\n1. Log in to the Tata Neu app & click on finance,\\n2. Go to the ‘Credit Cards’ section, then go to the dashboard,\\n3. Click on ‘view card details’,\\n4. You will be directed to the HDFC Bank page. Enter the OTP sent to your registered mobile no. to check your Tata Neu HDFC Bank Credit Card details.',
#   'source': 'PVA HDFC FAQs.xlsx',
#   'row': 714},
#  {'user_question': 'How can I check my Tata NeuCard number?',
#   'agent_answer': 'Steps to check the details of your Tata Neu HDFC Bank Credit Card:\\n1. Log in to the Tata Neu app & click on finance,\\n2. Go to the ‘Credit Cards’ section, then go to the dashboard,\\n3. Click on ‘view card details’,\\n4. You will be directed to the HDFC Bank page. Enter the OTP sent to your registered mobile no. to check your Tata Neu HDFC Bank Credit Card details.',
#   'source': 'PVA HDFC FAQs.xlsx',
#   'row': 715},
#  {'user_question': 'How can I check my Tata NeuCard expiry?',
#   'agent_answer': 'Steps to check the details of your Tata Neu HDFC Bank Credit Card:\\n1. Log in to the Tata Neu app & click on finance,\\n2. Go to the ‘Credit Cards’ section, then go to the dashboard,\\n3. Click on ‘view card details’,\\n4. You will be directed to the HDFC Bank page. Enter the OTP sent to your registered mobile no. to check your Tata Neu HDFC Bank Credit Card details.',
#   'source': 'PVA HDFC FAQs.xlsx',
#   'row': 716},
#  {'user_question': 'How can I check my Tata NeuCard CVV?',
#   'agent_answer': 'Steps to check the details of your Tata Neu HDFC Bank Credit Card:\\n1. Log in to the Tata Neu app & click on finance,\\n2. Go to the ‘Credit Cards’ section, then go to the dashboard,\\n3. Click on ‘view card details’,\\n4. You will be directed to the HDFC Bank page. Enter the OTP sent to your registered mobile no. to check your Tata Neu HDFC Bank Credit Card details.',
#   'source': 'PVA HDFC FAQs.xlsx',
#   'row': 717},
#  {'user_question': 'Is there any cashback available on my Tata NeuCard?',
#   'agent_answer': 'Your card is eligible only for reward points in the form of NeuCoins. However, if you are eligible for any cashback because of a merchant or promotional offer, the cashback will be credited to your respective Tata Neu HDFC Bank Credit Card account as per the terms & conditions of the offer.',
#   'source': 'PVA HDFC FAQs.xlsx',
#   'row': 718},
#  {'user_question': 'Cashbacks available on my Tata NeuCard transactions',
#   'agent_answer': 'Your card is eligible only for reward points in the form of NeuCoins. However, if you are eligible for any cashback because of a merchant or promotional offer, the cashback will be credited to your respective Tata Neu HDFC Bank Credit Card account as per the terms & conditions of the offer.',
#   'source': 'PVA HDFC FAQs.xlsx',
#   'row': 719},
#  {'user_question': 'Cashbacks available on my HDFC Bank credit card transactions',
#   'agent_answer': 'Your card is eligible only for reward points in the form of NeuCoins. However, if you are eligible for any cashback because of a merchant or promotional offer, the cashback will be credited to your respective Tata Neu HDFC Bank Credit Card account as per the terms & conditions of the offer.',
#   'source': 'PVA HDFC FAQs.xlsx',
#   'row': 720},
#  {'user_question': 'Cashback benefits in my Tata NeuCard',
#   'agent_answer': 'Your card is eligible only for reward points in the form of NeuCoins. However, if you are eligible for any cashback because of a merchant or promotional offer, the cashback will be credited to your respective Tata Neu HDFC Bank Credit Card account as per the terms & conditions of the offer.',
#   'source': 'PVA HDFC FAQs.xlsx',
#   'row': 721},
#  {'user_question': 'Cashback feature in my HDFC Bank credit card',
#   'agent_answer': 'Your card is eligible only for reward points in the form of NeuCoins. However, if you are eligible for any cashback because of a merchant or promotional offer, the cashback will be credited to your respective Tata Neu HDFC Bank Credit Card account as per the terms & conditions of the offer.',
#   'source': 'PVA HDFC FAQs.xlsx',
#   'row': 722},
#  {'user_question': 'Any cashback available in the Tata Neu credit card',
#   'agent_answer': 'Your card is eligible only for reward points in the form of NeuCoins. However, if you are eligible for any cashback because of a merchant or promotional offer, the cashback will be credited to your respective Tata Neu HDFC Bank Credit Card account as per the terms & conditions of the offer.',
#   'source': 'PVA HDFC FAQs.xlsx',
#   'row': 723},
#  {'user_question': 'Are there any cashbacks available on my Tata NeuCard transactions?',
#   'agent_answer': 'Your card is eligible only for reward points in the form of NeuCoins. However, if you are eligible for any cashback because of a merchant or promotional offer, the cashback will be credited to your respective Tata Neu HDFC Bank Credit Card account as per the terms & conditions of the offer.',
#   'source': 'PVA HDFC FAQs.xlsx',
#   'row': 724},
#  {'user_question': 'Are there any cashbacks available on my Tata Neu HDFC Bank credit card transactions?',
#   'agent_answer': 'Your card is eligible only for reward points in the form of NeuCoins. However, if you are eligible for any cashback because of a merchant or promotional offer, the cashback will be credited to your respective Tata Neu HDFC Bank Credit Card account as per the terms & conditions of the offer.',
#   'source': 'PVA HDFC FAQs.xlsx',
#   'row': 725},
#  {'user_question': 'Will I get cashback on the Tata NeuCard usage?',
#   'agent_answer': 'Your card is eligible only for reward points in the form of NeuCoins. However, if you are eligible for any cashback because of a merchant or promotional offer, the cashback will be credited to your respective Tata Neu HDFC Bank Credit Card account as per the terms & conditions of the offer.',
#   'source': 'PVA HDFC FAQs.xlsx',
#   'row': 726},
#  {'user_question': 'Cashbacks available on Tata NeuCard',
#   'agent_answer': 'Your card is eligible only for reward points in the form of NeuCoins. However, if you are eligible for any cashback because of a merchant or promotional offer, the cashback will be credited to your respective Tata Neu HDFC Bank Credit Card account as per the terms & conditions of the offer.',
#   'source': 'PVA HDFC FAQs.xlsx',
#   'row': 727},
#  {'user_question': 'Cashbacks available on my HDFC Bank credit card',
#   'agent_answer': 'Your card is eligible only for reward points in the form of NeuCoins. However, if you are eligible for any cashback because of a merchant or promotional offer, the cashback will be credited to your respective Tata Neu HDFC Bank Credit Card account as per the terms & conditions of the offer.',
#   'source': 'PVA HDFC FAQs.xlsx',
#   'row': 728},
#  {'user_question': 'Where can I see the active offers on my Tata NeuCard?',
#   'agent_answer': 'Simply click here to view all the active offers: \\n1. https://offers.smartbuy.hdfcbank.com/\\n2. https://www.tatadigital.com/offer-zone/offers---bundles',
#   'source': 'PVA HDFC FAQs.xlsx',
#   'row': 729},
#  {'user_question': 'View active offers in my Tata NeuCard',
#   'agent_answer': 'Simply click here to view all the active offers: \\n1. https://offers.smartbuy.hdfcbank.com/\\n2. https://www.tatadigital.com/offer-zone/offers---bundles',
#   'source': 'PVA HDFC FAQs.xlsx',
#   'row': 730},
#  {'user_question': 'View active offers in my Tata Neu HDFC Bank credit Card',
#   'agent_answer': 'Simply click here to view all the active offers: \\n1. https://offers.smartbuy.hdfcbank.com/\\n2. https://www.tatadigital.com/offer-zone/offers---bundles',
#   'source': 'PVA HDFC FAQs.xlsx',
#   'row': 731},
#  {'user_question': 'List of offers in my HDFC Bank credit card',
#   'agent_answer': 'Simply click here to view all the active offers: \\n1. https://offers.smartbuy.hdfcbank.com/\\n2. https://www.tatadigital.com/offer-zone/offers---bundles',
#   'source': 'PVA HDFC FAQs.xlsx',
#   'row': 732},
#  {'user_question': 'How to check offers in my Tata NeuCard',
#   'agent_answer': 'Simply click here to view all the active offers: \\n1. https://offers.smartbuy.hdfcbank.com/\\n2. https://www.tatadigital.com/offer-zone/offers---bundles',
#   'source': 'PVA HDFC FAQs.xlsx',
#   'row': 733},
#  {'user_question': 'HDFC Bank credit card offers',
#   'agent_answer': 'Simply click here to view all the active offers: \\n1. https://offers.smartbuy.hdfcbank.com/\\n2. https://www.tatadigital.com/offer-zone/offers---bundles',
#   'source': 'PVA HDFC FAQs.xlsx',
#   'row': 734},
#  {'user_question': 'Tata NeuCard offers',
#   'agent_answer': 'Simply click here to view all the active offers: \\n1. https://offers.smartbuy.hdfcbank.com/\\n2. https://www.tatadigital.com/offer-zone/offers---bundles',
#   'source': 'PVA HDFC FAQs.xlsx',
#   'row': 735},
#  {'user_question': 'How to check offer in my HDFC credit card',
#   'agent_answer': 'Simply click here to view all the active offers: \\n1. https://offers.smartbuy.hdfcbank.com/\\n2. https://www.tatadigital.com/offer-zone/offers---bundles',
#   'source': 'PVA HDFC FAQs.xlsx',
#   'row': 736},
#  {'user_question': 'How to check offer in my HDFC Bank credit card',
#   'agent_answer': 'Simply click here to view all the active offers: \\n1. https://offers.smartbuy.hdfcbank.com/\\n2. https://www.tatadigital.com/offer-zone/offers---bundles',
#   'source': 'PVA HDFC FAQs.xlsx',
#   'row': 737},
#  {'user_question': 'How can I view the active offers in my Tata NeuCard?',
#   'agent_answer': 'Simply click here to view all the active offers: \\n1. https://offers.smartbuy.hdfcbank.com/\\n2. https://www.tatadigital.com/offer-zone/offers---bundles',
#   'source': 'PVA HDFC FAQs.xlsx',
#   'row': 738},
#  {'user_question': 'Where can I view list of all offers active in my Tata NeuCard?',
#   'agent_answer': 'Simply click here to view all the active offers: \\n1. https://offers.smartbuy.hdfcbank.com/\\n2. https://www.tatadigital.com/offer-zone/offers---bundles',
#   'source': 'PVA HDFC FAQs.xlsx',
#   'row': 739},
#  {'user_question': 'View active offers in my HDFC Bank credit card',
#   'agent_answer': 'Simply click here to view all the active offers: \\n1. https://offers.smartbuy.hdfcbank.com/\\n2. https://www.tatadigital.com/offer-zone/offers---bundles',
#   'source': 'PVA HDFC FAQs.xlsx',
#   'row': 740},
#  {'user_question': 'View active offers in my HDFC Credit Card',
#   'agent_answer': 'Simply click here to view all the active offers: \\n1. https://offers.smartbuy.hdfcbank.com/\\n2. https://www.tatadigital.com/offer-zone/offers---bundles',
#   'source': 'PVA HDFC FAQs.xlsx',
#   'row': 741},
#  ...]

# %%
FaqData().export_faq(faqs)

# %%
pine_docs = pinecone_db.read_files(file_names=['joined_faq.csv'],
                                   directory_path='/content/drive/MyDrive/StanfordLLM/qa_data/faq_qa/')

pinecone_db.load_docs(pine_docs)
# pinecone_db.load_docs(pine_docs[0:100])

# %%
pine_docs[0]
# Out:
# Document(page_content='"How do I find invoices for my past orders?? Don\'t worry, a copy of your invoice will be emailed to your registered email ID. You can also visit \'Order History\' in the \'My Account\' section of the Tata CliQ app to find a copy of your invoice."\n"How will I know that my refund has been initiated?? You never have to worry about that. Tata CLiQ will send you an SMS and email confirming the initiation of your refund. Your refund should reach you within 3-4 working days. In the case of CLiQ Cash refund, the same will be processed in one business day."\n"I still haven’t got my refund. Why?? If you’ve received a confirmation on the approval of your refund, you will definitely get it. However, in rare cases, there are technical difficulties that can delay refund transfers. If the wait seems too long, you can always contact the Tata CLiQ Customer Care team for support."', metadata={'source': '/content/drive/MyDrive/StanfordLLM/qa_data/faq_qa/joined_faq.csv'})

# %% [markdown]
# ### Load docs

# %%
pine_docs = pinecone_db.read_files(file_names=['pay-user.txt',
                                               'payoff-sale.txt',
                                               'refer-and-earn.txt',
                                               'sale-parade.txt',
                                               'savings-calculator.txt',
                                               'seller-terms.txt',
                                               'tdl-privacy.txt',
                                               'terms-conditions.txt',
                                               'tpl-privacy.txt'],
                                   directory_path='/content/drive/MyDrive/StanfordLLM/qa_data/legal_qa/')

pinecone_db.load_docs(pine_docs)
# pinecone_db.load_docs(pine_docs[0:100])

# %%
pinecone_db.__str__(), pine_docs[0]
# Out:
# ['quickstart']
# IndexDescription(name='quickstart', metric='cosine', replicas=1, dimension=768.0, shards=1, pods=1, pod_type='starter', status={'ready': True, 'state': 'Ready'}, metadata_config=None, source_collection='')
# (None,
#  Document(page_content='TATA PAY USER AGREEMENT', metadata={'source': '/content/drive/MyDrive/StanfordLLM/qa_data/legal_qa/pay-user.txt'}))

# %% [markdown]
# ### Query

# %%
questions = ["What is NeuPass",
             "Tata Neu eligibility"
             ]

# %%
for q in questions:
    answer = pinecone_db.select_by_text(q)
    # print(answer)
    hit = answer['matches'][0]
    print("Q: " + q)
    print("A: " + hit['metadata']['text'] + " " + hit['metadata']['source'] + " " + str(hit['score']))
    print("---")
# Out:
# Q: What is NeuPass
# A: "What is NeuPass?? NeuPass is a rewards program from Tata Neu packed with benefits across brands. Earn minimum 5% NeuCoins* every time you shop and enjoy free deliveries when you shop on Tata Neu. Use your NeuCoins to save whenever you shop, book travel, dine, and more!\n\nFor more details, check https://www.tatadigital.com/v2/cdp/about-neupass"
# "loyaltyprogram? NeuPass is a rewards program from Tata Neu packed with benefits across brands. Earn minimum 5% NeuCoins* every time you shop and enjoy free deliveries when you shop on Tata Neu. Use your NeuCoins to save whenever you shop, book travel, dine, and more!\n\nFor more details, check https://www.tatadigital.com/v2/cdp/about-neupass" /content/drive/MyDrive/StanfordLLM/qa_data/faq_qa/joined_faq.csv 0.671044767
# ---
# Q: Tata Neu eligibility
# A: "Am I eligible for the Tata NeuCard?? The Tata Neu HDFC Bank Credit Card is a Co-branded credit card launched in partnership with HDFC Bank. Currently, this is an invite-only programme on Tata Neu. It will be made available for all Tata Neu customers very soon.
# •	The applicant must be a Salaried Professional, Self-Employed Professional or Self-Employed Businessperson.
# •	Existing HDFC Bank Credit Card holders can also apply for this Card. The Credit Limit of existing HDFC Bank Credit Card will be shared with the Tata Neu HDFC Bank Credit Card.
# Eligibility condition for salaried customers:
# 1.	Age group: 21-60 years
# 2.	Gross Monthly Income > ₹ 25,000 for Tata Neu Plus HDFC Bank Credit Card.
# 3.	Gross Monthly Income > ₹ 100,000 for Tata Neu Infinity HDFC Bank Credit Card. /content/drive/MyDrive/StanfordLLM/qa_data/faq_qa/joined_faq.csv 0.753708661
# ---
